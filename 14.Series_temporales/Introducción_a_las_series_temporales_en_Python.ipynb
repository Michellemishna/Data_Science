# %% [markdown]
# ### Importar los paquetes

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### Importar los Datos

# %%
df = pd.read_csv("/home/unixx/linear_regression/14.Series_temporales/Index2018.csv")

# %% [markdown]
# ### Examinar los datos

# %%
df.head()
# Out:
#          date     spx      dax     ftse    nikkei
# 0  07/01/1994  469.90  2224.95  3445.98  18124.01
# 1  10/01/1994  475.27  2225.00  3440.58  18443.44
# 2  11/01/1994  474.13  2228.10  3413.77  18485.25
# 3  12/01/1994  474.17  2182.06  3372.02  18793.88
# 4  13/01/1994  472.47  2142.37  3360.01  18577.26

# %%
#¿Hay nans? 
df.isna().sum()
# Out:
# date      0
# spx       0
# dax       0
# ftse      0
# nikkei    0
# dtype: int64

# %% [markdown]
# ### Dibujar una serie temporal con Matplotlib

# %%
df.spx.plot(figsize=(20,5), title = "S&P500 Prices")
plt.show()

# %%
df.ftse.plot(figsize=(20,5), title = "FTSE100 Prices")
plt.show()

# %%
# Dos series en el mismo gráfico
df.spx.plot(figsize=(20,5), title = "S&P500 Prices")
df.ftse.plot(figsize=(20,5), title = "FTSE100 Prices")
plt.title("S&P vs FTSE")
plt.show()

# %% [markdown]
# ### Convertir las fechas de texto a tipo fecha

# %%
df.head()
# Out:
#          date     spx      dax     ftse    nikkei
# 0  07/01/1994  469.90  2224.95  3445.98  18124.01
# 1  10/01/1994  475.27  2225.00  3440.58  18443.44
# 2  11/01/1994  474.13  2228.10  3413.77  18485.25
# 3  12/01/1994  474.17  2182.06  3372.02  18793.88
# 4  13/01/1994  472.47  2142.37  3360.01  18577.26

# %%
df.date = pd.to_datetime(df.date, dayfirst = True)
df.head()
# Out:
#         date     spx      dax     ftse    nikkei
# 0 1994-01-07  469.90  2224.95  3445.98  18124.01
# 1 1994-01-10  475.27  2225.00  3440.58  18443.44
# 2 1994-01-11  474.13  2228.10  3413.77  18485.25
# 3 1994-01-12  474.17  2182.06  3372.02  18793.88
# 4 1994-01-13  472.47  2142.37  3360.01  18577.26

# %% [markdown]
# ### Convertir la fecha en índice

# %%
df.set_index("date", inplace=True)
df.head()
# Out:
#                spx      dax     ftse    nikkei
# date
# 1994-01-07  469.90  2224.95  3445.98  18124.01
# 1994-01-10  475.27  2225.00  3440.58  18443.44
# 1994-01-11  474.13  2228.10  3413.77  18485.25
# 1994-01-12  474.17  2182.06  3372.02  18793.88
# 1994-01-13  472.47  2142.37  3360.01  18577.26

# %%
df.spx.plot(figsize=(20,5))
plt.title("S&P Prices", size = 24)
plt.show()

# %%
df.spx.plot(figsize=(20,5), title = "S&P500 Prices")
df.ftse.plot(figsize=(20,5), title = "FTSE100 Prices")
plt.title("S&P vs FTSE")
plt.show()

# %%
# Selección de un subdataset (por fechas)
df_after2007_before2010=df[(df.index >= '2007-01-01') & (df.index <= '2010-01-01')]
df_after2007_before2010.head()
# Out:
#                     spx      dax     ftse    nikkei
# date
# 2007-01-01  1418.300486  6596.92  6220.81  17225.83
# 2007-01-02  1418.300486  6681.13  6310.93  17225.83
# 2007-01-03  1416.602040  6691.32  6319.01  17225.83
# 2007-01-04  1418.341193  6674.40  6286.96  17353.67
# 2007-01-05  1409.707052  6593.09  6220.12  17091.59

# %%
df_after2007_before2010.spx.plot(figsize=(20,5), title = "S&P500 Prices")
df_after2007_before2010.ftse.plot(figsize=(20,5), title = "FTSE100 Prices")
plt.title("S&P vs FTSE")
plt.show()

# %%
# Selección de un año
df_2007=df[(df.index >= '2007-01-01') & (df.index <= '2007-12-31')]
df_2007.head()
df_2007.spx.plot(figsize=(20,5), title = "S&P500 Prices")
df_2007.ftse.plot(figsize=(20,5), title = "FTSE100 Prices")
plt.title("S&P vs FTSE")
plt.show()

# %%
# Selección de dos meses
df_2007_0102=df[(df.index >= '2007-01-01') & (df.index <= '2007-02-28')]
df_2007_0102.head()
df_2007_0102.spx.plot(figsize=(20,5), title = "S&P500 Prices")
df_2007_0102.ftse.plot(figsize=(20,5), title = "FTSE100 Prices")
plt.title("S&P vs FTSE")
plt.show()
